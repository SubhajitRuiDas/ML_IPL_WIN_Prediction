# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv('matches.csv')

# %%
match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
delivery = pd.read_csv('deliveries.csv/deliveries.csv')

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match.shape
# Out:
# (756, 18)

# %%
delivery.shape
# Out:
# (179078, 21)

# %%
delivery.groupby(['match_id','inning']).sum()['total_runs']
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
total_score_df =delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
## now i have to filter out the first inning value which is the total run or target for the second inning batting team
total_score_df[total_score_df['inning'] == 1]
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = ['Sunrisers Hyderabad', 'Mumbai Indians',
        'Royal Challengers Bangalore',
       'Kolkata Knight Riders','Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals',
       'Delhi Capitals']

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (641, 20)

# %%
match_df['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    626
# 1     15
# Name: count, dtype: int64

# %%
match_df = match_df[match_df['dl_applied'] == 0]

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match[['match_id','city','total_runs','winner']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 match[['match_id','city','total_runs','winner']]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
match_df[['match_id','city','total_runs','winner']]

# %%
match_df = match_df[['match_id','city','total_runs','winner']]

# %%
match_df.merge(delivery,on='match_id')
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 0              1  Hyderabad           207  Sunrisers Hyderabad       1
# 1              1  Hyderabad           207  Sunrisers Hyderabad       1
# 2              1  Hyderabad           207  Sunrisers Hyderabad       1
# 3              1  Hyderabad           207  Sunrisers Hyderabad       1
# 4              1  Hyderabad           207  Sunrisers Hyderabad       1
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 0              1  Hyderabad           207  Sunrisers Hyderabad       1
# 1              1  Hyderabad           207  Sunrisers Hyderabad       1
# 2              1  Hyderabad           207  Sunrisers Hyderabad       1
# 3              1  Hyderabad           207  Sunrisers Hyderabad       1
# 4              1  Hyderabad           207  Sunrisers Hyderabad       1
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 delivery_df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
delivery_df.shape
# Out:
# (72413, 24)

# %%
delivery_df
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 125            1  Hyderabad           207  Sunrisers Hyderabad       2
# 126            1  Hyderabad           207  Sunrisers Hyderabad       2
# 127            1  Hyderabad           207  Sunrisers Hyderabad       2
# 128            1  Hyderabad           207  Sunrisers Hyderabad       2
# 129            1  Hyderabad           207  Sunrisers Hyderabad       2
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 125            1  Hyderabad           207  Sunrisers Hyderabad       2
# 126            1  Hyderabad           207  Sunrisers Hyderabad       2
# 127            1  Hyderabad           207  Sunrisers Hyderabad       2
# 128            1  Hyderabad           207  Sunrisers Hyderabad       2
# 129            1  Hyderabad           207  Sunrisers Hyderabad       2
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\1894988650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 125            1  Hyderabad           207  Sunrisers Hyderabad       2
# 126            1  Hyderabad           207  Sunrisers Hyderabad       2
# 127            1  Hyderabad           207  Sunrisers Hyderabad       2
# 128            1  Hyderabad           207  Sunrisers Hyderabad       2
# 129            1  Hyderabad           207  Sunrisers Hyderabad       2
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score'] + 1
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\2144281317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score'] + 1

# %%
delivery_df
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 125            1  Hyderabad           207  Sunrisers Hyderabad       2
# 126            1  Hyderabad           207  Sunrisers Hyderabad       2
# 127            1  Hyderabad           207  Sunrisers Hyderabad       2
# 128            1  Hyderabad           207  Sunrisers Hyderabad       2
# 129            1  Hyderabad           207  Sunrisers Hyderabad       2
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\517047302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city  total_runs_x               winner  inning  \
# 125            1  Hyderabad           207  Sunrisers Hyderabad       2
# 126            1  Hyderabad           207  Sunrisers Hyderabad       2
# 127            1  Hyderabad           207  Sunrisers Hyderabad       2
# 128            1  Hyderabad           207  Sunrisers Hyderabad       2
# 129            1  Hyderabad           207  Sunrisers Hyderabad       2
# ...          ...        ...           ...                  ...     ...
# 149573     11415  Hyderabad           152       Mumbai Indians       2
# 149574     11415  Hyderabad           152       Mumbai Indians       2
# 149575     11415  Hyderabad           152       Mumbai Indians       2
# 149576     11415  Hyderabad           152       Mumbai Indians       2
# 149577     11415  Hyderabad           152       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
# Replace NaN with 0 and player names with 1
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].notna().astype(int)

# Compute cumulative wickets per match
delivery_df['wickets'] = 10 - delivery_df.groupby('match_id')['player_dismissed'].cumsum()

# Show output
delivery_df.head()
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\2708808166.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].notna().astype(int)
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\2708808166.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets'] = 10 - delivery_df.groupby('match_id')['player_dismissed'].cumsum()
# ...

# %%
delivery_df['curr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\2629856900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['curr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
delivery_df.tail()
# Out:
#         match_id       city  total_runs_x          winner  inning  \
# 149573     11415  Hyderabad           152  Mumbai Indians       2
# 149574     11415  Hyderabad           152  Mumbai Indians       2
# 149575     11415  Hyderabad           152  Mumbai Indians       2
# 149576     11415  Hyderabad           152  Mumbai Indians       2
# 149577     11415  Hyderabad           152  Mumbai Indians       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        extra_runs total_runs_y  player_dismissed  dismissal_kind    fielder  \
# ...

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\2241449921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df.head()
# Out:
#      match_id       city  total_runs_x               winner  inning  \
# 125         1  Hyderabad           207  Sunrisers Hyderabad       2
# 126         1  Hyderabad           207  Sunrisers Hyderabad       2
# 127         1  Hyderabad           207  Sunrisers Hyderabad       2
# 128         1  Hyderabad           207  Sunrisers Hyderabad       2
# 129         1  Hyderabad           207  Sunrisers Hyderabad       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... total_runs_y player_dismissed  dismissal_kind  \
# 125       CH Gayle  ...            1                0             NaN
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Temp\ipykernel_21772\955537649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df.tail()
# Out:
#         match_id       city  total_runs_x          winner  inning  \
# 149573     11415  Hyderabad           152  Mumbai Indians       2
# 149574     11415  Hyderabad           152  Mumbai Indians       2
# 149575     11415  Hyderabad           152  Mumbai Indians       2
# 149576     11415  Hyderabad           152  Mumbai Indians       2
# 149577     11415  Hyderabad           152  Mumbai Indians       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        player_dismissed dismissal_kind    fielder  current_score  runs_left  \
# ...

# %%
final_df = delivery_df[['batting_team','bowling_team','city','total_runs_x','runs_left','balls_left','wickets','curr','rrr','result']]

# %%
final_df
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149577          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         total_runs_x  runs_left  balls_left  wickets      curr        rrr  \
# 125              207        207         119       10  6.000000  10.436975
# ...

# %%
final_df.sample()
# Out:
#                batting_team                 bowling_team    city  \
# 113763  Chennai Super Kings  Royal Challengers Bangalore  Ranchi
#
#         total_runs_x  runs_left  balls_left  wickets     curr       rrr  \
# 113763           139         94          73        9  5.87234  7.726027
#
#         result
# 113763       1

# %%
final_df.sample()
# Out:
#                 batting_team      bowling_team    city  total_runs_x  \
# 49928  Kolkata Knight Riders  Rajasthan Royals  Jaipur           159
#
#        runs_left  balls_left  wickets      curr       rrr  result
# 49928         59          52        9  8.911765  6.807692       1

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#               batting_team           bowling_team     city  total_runs_x  \
# 44965  Chennai Super Kings  Kolkata Knight Riders  Chennai           139
#
#        runs_left  balls_left  wickets  curr   rrr  result
# 44965         14          50        9  10.8  1.68       1

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df["balls_left"] != 0]

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.describe()
# Out:
#        total_runs_x     runs_left    balls_left       wickets          curr  \
# count  57073.000000  57073.000000  57073.000000  57073.000000  57073.000000
# mean     165.717975     93.539292     62.848300      7.554676      7.449421
# std       29.274364     49.914304     33.247654      2.125338      2.261936
# min       65.000000    -11.000000     -2.000000      0.000000      0.000000
# 25%      147.000000     54.000000     35.000000      6.000000      6.272727
# 50%      165.000000     93.000000     64.000000      8.000000      7.500000
# 75%      185.000000    131.000000     92.000000      9.000000      8.700000
# max      250.000000    250.000000    119.000000     10.000000     36.000000
#
#                 rrr
# count  57073.000000
# mean      10.576929
# std       14.208107
# min     -516.000000
# 25%        7.263158
# 50%        8.973451
# 75%       11.027027
# max      684.000000

# %%
X_train
# Out:
#                  batting_team                 bowling_team        city  \
# 115852  Kolkata Knight Riders              Kings XI Punjab  Chandigarh
# 108901       Delhi Daredevils             Rajasthan Royals      Mumbai
# 39348         Deccan Chargers               Mumbai Indians      Mumbai
# 20194        Rajasthan Royals          Chennai Super Kings      Mumbai
# 74133     Chennai Super Kings              Kings XI Punjab  Chandigarh
# ...                       ...                          ...         ...
# 12655        Rajasthan Royals          Chennai Super Kings      Jaipur
# 42991         Deccan Chargers  Royal Challengers Bangalore   Bangalore
# 116131         Mumbai Indians  Royal Challengers Bangalore      Mumbai
# 46574        Delhi Daredevils              Deccan Chargers       Delhi
# 132989    Sunrisers Hyderabad  Royal Challengers Bangalore   Bengaluru
#
#         total_runs_x  runs_left  balls_left  wickets       curr        rrr
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\Subhajit Ruidas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
# ...

# %%
print(pipe)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8032798374097694

# %%
pipe.predict_proba(X_test)[8]
# Out:
# array([0.08844894, 0.91155106])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
match_summary(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 match_summary(2)
#
# Cell In[75], line 2, in match_summary(row)
#       1 def match_summary(row):
# ----> 2     print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))
#
# TypeError: 'int' object is not subscriptable
